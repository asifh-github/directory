# %%
import pandas as pd

# %%
# read csv1
csv1 = pd.read_csv("pagecounts-20190509-120000.txt", sep=' ', header=None, index_col=1,
        names=['lang', 'page', 'views', 'bytes'])
csv1
# Out:
#                             lang  views  bytes
# page
# Athol_Moffitt                 en      1      0
# Diction                       en      1      0
# Person-centered_therapy       en     10      0
# Dave_Dobbyn                   en      2      0
# MAZ-7310                      en      5      0
# ...                          ...    ...    ...
# Holderness_Rural_District     en      1      0
# G-mik                         en      4      0
# Little_Go_Beep                en      1      0
# Benoît                        en      2      0
# Saints_Row:_Gat_Out_of_Hell   en      1      0
#
# [2500 rows x 3 columns]

# %%
# read csv2
csv2 = pd.read_csv("pagecounts-20190509-130000.txt", sep=' ', header=None, index_col=1,
        names=['lang', 'page', 'views', 'bytes'])
csv2
# Out:
#                                          lang  views  bytes
# page
# 1949_Grand_Prix_motorcycle_racing_season   en      2      0
# 1951_in_Brazil                             en      1      0
# 1976_Japanese_Grand_Prix                   en      1      0
# 1980_Campeonato_Brasileiro_Série_A         en      1      0
# 1980_NBA_Finals                            en      4      0
# ...                                       ...    ...    ...
# Zingiber_zerumbet                          en      2      0
# Zodiac_(film)                              en     52      0
# Zygomaticofacial_nerve                     en      1      0
# Üsküdar                                    en      5      0
# Ń                                          en      3      0
#
# [1241 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
# sort the values/views (desc) of csv1
csv1_sorted = csv1.sort_values(['views'], ascending=False)
csv1_sorted
# Out:
#                                               lang  views  bytes
# page
# Java_(programming_language)                     en    128      0
# Universally_unique_identifier                   en    108      0
# Alex_Ferguson                                   en     72      0
# Citric_acid_cycle                               en     58      0
# Senegal                                         en     53      0
# ...                                            ...    ...    ...
# Paul_Flato                                      en      1      0
# List_of_French_Open_women's_singles_champions   en      1      0
# Yacuma                                          en      1      0
# Steradians                                      en      1      0
# Saints_Row:_Gat_Out_of_Hell                     en      1      0
#
# [2500 rows x 3 columns]

# %%
# distribution of views
# plot csv1_sorted using index 0 to n-1 range
plt.plot(csv1_sorted['views'].values)
# add title and label the axes
plt.title("Popularity Distribution of Pages")
plt.xlabel("Rank")
plt.ylabel("Views")
# Out:
# Text(0, 0.5, 'Views')

# %%
# hourly views
# create a new df containing views from csv1 & csv2 
new_df = pd.DataFrame(data=dict(views1=csv1['views'], views2=csv2['views']))
new_df
# Out:
#                                  views1  views2
# page
# $1000                                 4     NaN
# 12_Love_Stories                       1     NaN
# 1306                                  1     NaN
# 14th_New_York_State_Legislature       1     NaN
# 1571                                  1     NaN
# ...                                 ...     ...
# sputtering                            7     NaN
# Ásgeir_Ásgeirsson                     1     NaN
# Évelyne_Sullerot                      1     NaN
# Üsküdar                               1     5.0
# Ń                                     5     3.0
#
# [2500 rows x 2 columns]

# %%
# plot csv1_data/views1 on x-axis $ csv2_data/views on y-axis 
# scale values to log scale
# add title and label the axes
plt.plot(new_df['views1'], new_df['views2'], 'bo')
plt.title("Correlation of views on pages btwn two constcutive hours")
plt.xlabel("Hour 1 views (in log scale)")
plt.ylabel("Hour 2 views (in log scale)")
plt.xscale("log")
plt.yscale("log")

# %%
plt.show()
